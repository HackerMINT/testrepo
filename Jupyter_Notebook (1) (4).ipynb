# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # **My Jupyter Notebook on IBM Watson Studio**

# %% [markdown]
# #### **CHEKURI NIKHIL**
# Data Scientist

# %% [markdown]
# _The Passion that drives me while working with data and derive meaningful conclusions and help build actionable solutions so I'm enthusiastic about data science considering how quickly technology is changing the profession_

# %% [markdown]
# ### **The following code returns the factorial of 7 using recursion**

# %%
def factorial(n):
    if n == 0 or n == 1:
        return 1
    else:
        return n * factorial(n-1)
factorial(7)
# Out:
# 5040

# %% [markdown]
# Indian Cricket Team
#  - **virat**
#  - **rohit**
#  - **rahul**
#  - **pandya**
#  - **bhuvi**
#  - **harshal**
#
#  |Name   | Description | Rank  |
#  |:---   |   :----:    |   ---:|
#  |Virat  | Batsman     |  1    |
#  |Rohit  | Batsman     |  2    |
#  |Bumrah | Bowler      |  1    |
#  |Jadeja | All rounder |  1    |
#
#  1.pant<br>
#  2.dk<br>
#  3.jadeja<br>
#  4.umran
#
#  ~~manish pandey~~<br>
#  ~~saha~~
#  ![virat%20pic.jpg](attachment:virat%20pic.jpg)
#
#  [www.ibm.com]
